# %% [markdown]
# Speed Bumps

# %% [markdown]
# Introduction: Speed Bumps are very important for the safety of neighborhoods. Speed Bumps slow down traffic, reducing speed, making it safer for pedestrians to walk and children to play. Calming traffic creates a sense of community in neighborhoods, making a safe area where people can feel comfortable. Speed Bumps can also lower accident rates in a neighborhood. They make roads safer not just for cars, but most importantly for people.

# %% [markdown]
# This is the importation of the data set:

# %%
import pandas as pd

df = pd.read_csv('speed bump data.csv')

df.head(150)
# Out:
#     _id          id  hump_id  locator_address_number locator_street  pavement  \
# 0     1   430808404        1                  4337.0      Saline St      9257
# 1    34  1520886592        2                     NaN   Summerset Dr     15346
# 2    67   858537521        3                   511.0       Gold Way      1755
# 3    68   297775878        4                   547.0       Gold Way      1755
# 4    69  1061197751        5                   593.0       Gold Way      1755
# ..  ...         ...      ...                     ...            ...       ...
# 74  342  2047879882       75                  5343.0   Mossfield St     19094
# 75  343  1379652923       76                   622.0     Maytide St     15244
# 76  344   965432088       77                   378.0     Maytide St     15244
# 77  345   724005157       78                   217.0     Maytide St     16410
# 78  346  1352764849       79                   273.0     Maytide St     16410
#
#    speed_hump_material         neighborhood  council_district  ward  \
# 0              Asphalt  Squirrel Hill South                 5    14
# 1                  NaN  Squirrel Hill South                 5    14
# 2              Asphalt        North Oakland                 6     5
# 3              Asphalt        North Oakland                 6     5
# 4              Asphalt        North Oakland                 6     5
# ..                 ...                  ...               ...   ...
# 74             Asphalt      Stanton Heights                 9    10
# 75             Asphalt            Overbrook                 4    32
# 76             Asphalt              Carrick                 4    29
# 77             Asphalt              Carrick                 4    29
# 78             Asphalt              Carrick                 4    29
#
#           tract  public_works_division  pli_division  police_zone fire_zone  \
# 0   42003141400                      3            14            4      2-15
# 1   42003141400                      3            14            4      2-20
# 2   42003562000                      3             5            4      2-23
# 3   42003562000                      3             5            4      2-23
# 4   42003562000                      3             5            4      2-23
# ..          ...                    ...           ...          ...       ...
# 74  42003100500                      2            10            5       3-4
# 75  42003320400                      5            32            3      4-23
# 76  42003290400                      3            29            3      4-23
# 77  42003290400                      3            29            3      4-23
# 78  42003290400                      3            29            3      4-23
#
#      latitude  longitude
# 0   40.419835 -79.926062
# 1   40.425040 -79.912040
# 2   40.456746 -79.954521
# 3   40.457333 -79.954899
# 4   40.458061 -79.955355
# ..        ...        ...
# 74  40.472015 -79.934367
# 75  40.383984 -79.990647
# 76  40.384498 -79.986498
# 77  40.384359 -79.982626
# 78  40.384444 -79.983827
#
# [79 rows x 17 columns]

# %% [markdown]
# These are the neighborhoods in order from most speed bumps to least speed bumps:

# %%
import pandas as pd
df = pd.read_csv('speed bump data.csv')
speedhump_counts = (
    df.groupby('neighborhood')       
      .size()                        
      .reset_index(name='Hump_Count')  
      .sort_values('Hump_Count', ascending=False)  
)
print(speedhump_counts)
# Out:
#            neighborhood  Hump_Count
# 15  Squirrel Hill South          18
# 2               Carrick           9
# 11          Polish Hill           6
# 8         North Oakland           6
# 10          Perry North           4
# 1             Brookline           4
# 6        Homewood South           4
# 13    South Side Slopes           4
# 17           Upper Hill           4
# 0            Bloomfield           3
# 4              Garfield           3
# 12     South Side Flats           3
# 14  Squirrel Hill North           3
# 7      Mount Washington           3
# 5         Highland Park           2
# 3       Central Oakland           1
# 9             Overbrook           1
# 16      Stanton Heights           1

# %% [markdown]
# These are the top 10 neighborhoods with the most speed bumps:

# %%
import pandas as pd

df = pd.read_csv('speed bump data.csv')
print(df.columns)

hump_counts = (
    df.groupby('neighborhood')      
      .size()                       
      .reset_index(name='Count')    
      .sort_values('Count', ascending=False)  
)
print(hump_counts.head(30))
# Out:
# Index(['_id', 'id', 'hump_id', 'locator_address_number', 'locator_street',
#        'pavement', 'speed_hump_material', 'neighborhood', 'council_district',
#        'ward', 'tract', 'public_works_division', 'pli_division', 'police_zone',
#        'fire_zone', 'latitude', 'longitude'],
#       dtype='object')
#            neighborhood  Count
# 15  Squirrel Hill South     18
# 2               Carrick      9
# 11          Polish Hill      6
# 8         North Oakland      6
# 10          Perry North      4
# 1             Brookline      4
# 6        Homewood South      4
# 13    South Side Slopes      4
# 17           Upper Hill      4
# 0            Bloomfield      3
# 4              Garfield      3
# 12     South Side Flats      3
# 14  Squirrel Hill North      3
# 7      Mount Washington      3
# 5         Highland Park      2
# 3       Central Oakland      1
# 9             Overbrook      1
# 16      Stanton Heights      1

# %% [markdown]
# This is a bar chart with the top 10 neighborhoods with speed bumps:

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('speed bump data.csv')
speedhump_counts = (
    df.groupby('neighborhood')       
      .size()                        
      .reset_index(name='Hump_Count')  
      .sort_values('Hump_Count', ascending=False)  
)

speedhump_counts.head(10).plot(
    x='neighborhood',
    y='Hump_Count',
    kind='bar',
    figsize=(8,5),
    title='Top 10 Neighborhoods with the Most Speed Humps',
    legend=False,
    color='skyblue'
)
plt.xlabel('neighborhood')
plt.ylabel('Number of Speed Humps')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Final Best Neighborhood:
# Point based on ranking from 1-10
# Squirrel Hill South- 10 points
# Carrick-9 points
# Polish Hill-8 points
# North Oakland-7 points
# Perry North-6 points
# Brookline-5 points
# Homewood South-4 points
# South Side Slopes-3 points
# Upper Hill-2 points
# Bloomfield-1 points
